# %%
import pandas as pd
from pyspark.sql.functions import *
from pyspark.sql.types import *
files = [
{"file": "bulk_rides"},
{"file": "map_cities"},
{"file":"map_cancellation_reasons"},
{"file":"map_payment_methods"},
{"file":"map_ride_statuses"},
{"file":"map_vehicle_makes"},
{"file":"map_vehicle_types"}
]
for file in files:
#I prefer to hide the URL just in case since I dont fully understand how azure bills works
#    url = 
#after the '?' its the token access shared of the containers
    df= pd.read_json(url)
    df_spark = spark.createDataFrame(df)


if not spark.catalog.tableExists("uber.bronze.bulk_rides"):
    df_spark.write.format("delta")\
            .mode("overwrite")\
            .saveAsTable(f"uber.bronze.bulk_rides")
    print("This will not run more than 1 time")

# %%
df = spark.read.table('uber.bronze.rides_raw')
df.display()

# %%
# %sql
select * from uber.bronze.stg_rides

# %%
# %sql
select * from uber.bronze.bulk_rides

# %%
# %sql
select * from uber.bronze.map_cancellation_reasons

# %%
# %sql
select * from uber.bronze.map_cities

# %%
# %sql
select * from uber.bronze.map_payment_methods

# %%
# %sql
select * from uber.bronze.map_ride_statuses

# %%
# %sql
select * from uber.bronze.map_vehicle_makes

# %%
# %sql
select * from uber.bronze.map_vehicle_types
